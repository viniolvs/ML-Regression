# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error
from sklearn.neural_network import MLPRegressor
from sklearn.svm import SVR
from sklearn.ensemble import RandomForestRegressor

# %% [markdown]
# Define as bases de treino e teste

# %%
teste = pd.read_csv("teste.csv")
teste_variaveis = teste.iloc[:,1:11]
teste_quality = teste.iloc[:,-1]

treino = pd.read_csv("treino.csv")
treino_variaveis = treino.iloc[:,1:11]
treino_quality = treino.iloc[:,-1]
treino
# Out:
#       Unnamed: 0  fixed acidity  volatile acidity  citric acid  \
# 0            496            7.8              0.52         0.25
# 1            239            8.2              1.00         0.09
# 2            994           10.0              0.35         0.45
# 3            538           12.9              0.35         0.49
# 4           1434           10.2              0.54         0.37
# ...          ...            ...               ...          ...
# 1114         114            7.8              0.56         0.19
# 1115         379            8.3              0.42         0.38
# 1116         762            8.8              0.70         0.00
# 1117        1399            7.2              0.67         0.00
# 1118        1123           10.7              0.40         0.37
#
#       residual sugar  chlorides  free sulfur dioxide  total sulfur dioxide  \
# 0                1.9      0.081                 14.0                  38.0
# ...

# %%
teste
# Out:
#      Unnamed: 0  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0           756            6.3             0.980         0.01             2.0
# 1           116            8.3             0.540         0.28             1.9
# 2           702            7.0             0.640         0.02             2.1
# 3           873            9.1             0.210         0.37             1.6
# 4           629            7.6             0.685         0.23             2.3
# ..          ...            ...               ...          ...             ...
# 475         966            9.0             0.380         0.41             2.4
# 476         785            9.9             0.350         0.41             2.3
# 477        1098            8.0             0.310         0.45             2.1
# 478        1253            7.9             0.660         0.00             1.4
# 479         183            6.8             0.610         0.20             1.8
#
# ...

# %% [markdown]
# MLP regressor

# %%
#Define os melhores parâmetros utilizando a base de treino
erros = []
param = []

for i in range (10):
    for j in range (10):
        mlp = MLPRegressor(hidden_layer_sizes=(i+1,i+1,i+1),max_iter=(j+1)*50).fit(treino_variaveis, treino_quality)
        pred_mlp = mlp.predict(treino_variaveis)
        rmse = mean_squared_error(pred_mlp, treino_quality,squared=True)
        erros.append(rmse)
        param.append([i+1,(j+1)*50])

best_mlp = np.argmin(erros)
layers = param[best_mlp][0]
max_iter = param[best_mlp][1]

print(best_mlp,layers,max_iter)
# Out:
# /home/vinicius/.local/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/vinicius/.local/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (100) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/vinicius/.local/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (150) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/vinicius/.local/lib/python3.8/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# ...

# %%
#treina com os melhores parâmetros
mlp = MLPRegressor(hidden_layer_sizes=(layers,layers,layers),max_iter=max_iter).fit(treino_variaveis, treino_quality)
#testa com a base de teste
pred_mlp = mlp.predict(teste_variaveis)

#Avalia
print("MLP") 
#Raiz do erro quadrático médio
rmse = mean_squared_error(pred_mlp, teste_quality,squared=True)
print ("Raiz do erro quadrático médio =",rmse)

#Erro Quadrático Médio
mse = mean_squared_error(pred_mlp, teste_quality,squared=False)
print ("Erro Quadrático Médio =",mse)
# Out:
# MLP
# Raiz do erro quadrático médio = 0.6042477956813681
# Erro Quadrático Médio = 0.7773337736657067

# %% [markdown]
# SVR

# %%
#Define os melhores parâmetros

#kernel radial
erros = []
param = []

for i in range (10):
    for j in range (10):
        svr = SVR(kernel='rbf', C=(i+1)*10, gamma=(j+1)/10, epsilon=(j+1)/10).fit(treino_variaveis,treino_quality)
        pred = svr.predict(treino_variaveis)
        rmse = mean_squared_error(pred, treino_quality,squared=True)
        erros.append(rmse)
        param.append([(i+1)*10,(j+1)/10])

best_svr = np.argmin(erros)

C = param[best_svr][0]
gamma = param[best_svr][1]
epsilon = param[best_svr][1]

print(C,gamma,epsilon)
# Out:
# 100 0.1 0.1

# %%
#treina com os melhores parâmetros
svr = SVR(kernel='rbf', C=C, gamma=gamma, epsilon=epsilon).fit(treino_variaveis,treino_quality)
pred_svr = svr.predict(teste_variaveis)

#Avalia
print("SVR")
#Raiz do erro quadrático médio
rmse = mean_squared_error(pred_svr, teste_quality,squared=True)
print ("Raiz do erro quadrático médio =",rmse)

#Erro Quadrático Médio
mse = mean_squared_error(pred_svr, teste_quality,squared=False)
print ("Erro Quadrático Médio =",mse)
# Out:
# SVR
# Raiz do erro quadrático médio = 0.8653386848077986
# Erro Quadrático Médio = 0.9302358221482329

# %% [markdown]
# Random Forest Regressor

# %%
#Define os melhores parâmetros
erros = []
param = []

for i in range (7):
    for j in range (7):
        RFR = RandomForestRegressor(max_depth=i+1, random_state=j+1).fit(treino_variaveis,treino_quality)
        pred = RFR.predict(treino_variaveis)
        rmse = mean_squared_error(pred, treino_quality,squared=True)
        erros.append(rmse)
        param.append([i+1,j+1])

best_rfr = np.argmin(erros)
depth = param[best_rfr][0]
random = param[best_rfr][1]

print(depth,random)
# Out:
# 7 3

# %%
#treina com os melhores parâmetros
rfr = RandomForestRegressor(max_depth=depth, random_state=random).fit(treino_variaveis,treino_quality)
pred_rfr = rfr.predict(teste_variaveis)

#Avalia
print("RFR")
#Raiz do erro quadrático médio
rmse = mean_squared_error(pred_rfr, teste_quality,squared=True)
print ("Raiz do erro quadrático médio =",rmse)

#Erro Quadrático Médio
mse = mean_squared_error(pred_rfr, teste_quality,squared=False)
print ("Erro Quadrático Médio =",mse)
# Out:
# RFR
# Raiz do erro quadrático médio = 0.4312328093770083
# Erro Quadrático Médio = 0.6566831879810906
